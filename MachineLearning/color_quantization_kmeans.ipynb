# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
## .jpg .png -----> numpy arrays

# %%
image_as_array = mpimg.imread('palm_trees.jpg')
#image_as_array

# %%
image_as_array.shape  ####(H, W,C)
# Out:
# (1401, 934, 3)

# %%
#plt.figure(dpi=200)
plt.imshow(image_as_array)

# %%
###(H, W, C) ----> 2-D ( H*W, C)
(h,w,c) = image_as_array.shape

# %%
c
# Out:
# 3

# %%
image_as_array2d = image_as_array.reshape(h*w, c)

# %%
image_as_array2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
len(image_as_array2d.shape)
# Out:
# 2

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=6)

# %%
labels = model.fit_predict(image_as_array2d)

# %%
1401*934
# Out:
# 1308534

# %%
labels
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
model.cluster_centers_
# Out:
# array([[193.18277574, 154.53995034, 107.72753528],
#        [  2.78351406,   2.605042  ,   3.73404363],
#        [ 71.83616279, 109.85544767, 138.04241662],
#        [219.36341764, 134.98647308,  45.96424964],
#        [ 67.79688073,  62.01129751,  62.45058978],
#        [138.83182044, 144.41833579, 143.39988455]])

# %%
rgb_codes = model.cluster_centers_.round(0).astype(int)

# %%
rgb_codes
# Out:
# array([[193, 155, 108],
#        [  3,   3,   4],
#        [ 72, 110, 138],
#        [219, 135,  46],
#        [ 68,  62,  62],
#        [139, 144, 143]])

# %%
labels
# Out:
# array([2, 2, 2, ..., 1, 1, 1])

# %%
rgb_codes[labels]
# Out:
# array([[ 72, 110, 138],
#        [ 72, 110, 138],
#        [ 72, 110, 138],
#        ...,
#        [  3,   3,   4],
#        [  3,   3,   4],
#        [  3,   3,   4]])

# %%
image_as_array2d
# Out:
# array([[ 25,  89, 127],
#        [ 25,  89, 127],
#        [ 25,  89, 127],
#        ...,
#        [  9,   9,  11],
#        [ 10,  10,  12],
#        [ 10,  10,  12]], dtype=uint8)

# %%
quantized_image = np.reshape(rgb_codes[labels],(h,w,c))

# %%
plt.imshow(quantized_image)
